# %%
import csv

def write_into_csv(info_list):
    with open("student_info.csv", "a") as csv_file:
        writer = csv.writer(csv_file)
        
        if csv_file.tell()==0:
               writer.writerow(["Name", "Age", "Contact_Number", "Email_ID"])
        writer.writerow(info_list)

if __name__ == "__main__":
  condition = True
  student_num = 1

  while(condition):
        student_info = input("Enter student information for student #{} in the following format (Name Age Contact_Number Email_ID):".format(student_num))
        print("Entered Information= " + student_info)
    
        #split
        student_info_list = student_info.split(" ")
        print("Entered split up information is: "+str(student_info_list))
        
        print("\nThe Entered information is \nName: {}\nAge: {}\nContact_information: {}\nEmail_ID: {}"
              .format( student_info_list[0], student_info_list[1], student_info_list[2],  student_info_list[3]))
        
        choice_check=input("Is the entered information correct? (yes/no): ")
        
        if choice_check == "yes":
               write_into_csv(student_info_list) 
               
               condition_check = input("Enter (yes/no) if you want to enter information for another student: ")
               if condition_check == "yes":
                    condition = True
                    student_num = student_num + 1
               elif condition_check =="no":
                    condition = False
        elif choice_check =="no":
               print("\nPlease re-enter the value!")
# Out:
# Enter student information for student #1 in the following format (Name Age Contact_Number Email_ID):Rahul 21 64388 rahul@gmail.com
# Entered Information= Rahul 21 64388 rahul@gmail.com
# Entered split up information is: ['Rahul', '21', '64388', 'rahul@gmail.com']
#
# The Entered information is
# Name: Rahul
# Age: 21
# Contact_information: 64388
# Email_ID: rahul@gmail.com
# Is the entered information correct? (yes/no): yes
# Enter (yes/no) if you want to enter information for another student: yes
# Enter student information for student #2 in the following format (Name Age Contact_Number Email_ID):name 21 74778 hdkd
# Entered Information= name 21 74778 hdkd
# Entered split up information is: ['name', '21', '74778', 'hdkd']
#
# The Entered information is
# Name: name
# Age: 21
# Contact_information: 74778
# Email_ID: hdkd
# Is the entered information correct? (yes/no): no
#
# Please re-enter the value!
# Enter student information for student #2 in the following format (Name Age Contact_Number Email_ID):Raju 21 6373883 raju@gmail.com
# Entered Information= Raju 21 6373883 raju@gmail.com
# Entered split up information is: ['Raju', '21', '6373883', 'raju@gmail.com']
#
# The Entered information is
# Name: Raju
# Age: 21
# Contact_information: 6373883
# Email_ID: raju@gmail.com
# Is the entered information correct? (yes/no): yes
# Enter (yes/no) if you want to enter information for another student: yes
# Enter student information for student #3 in the following format (Name Age Contact_Number Email_ID):Ramesh 21 64838 ramesh2gamil.com
# Entered Information= Ramesh 21 64838 ramesh2gamil.com
# Entered split up information is: ['Ramesh', '21', '64838', 'ramesh2gamil.com']
#
# The Entered information is
# Name: Ramesh
# Age: 21
# Contact_information: 64838
# Email_ID: ramesh2gamil.com
# Is the entered information correct? (yes/no): yes
# Enter (yes/no) if you want to enter information for another student: no
